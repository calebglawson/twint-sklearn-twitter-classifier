# %%
import pandas as pd
import sqlite3
conn = sqlite3.connect("./specifics/intake.db")
df = pd.read_sql_query("select * from user_stats;", conn)
df.head()
conn.close()

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

g = sns.FacetGrid(df, col="is_on_watchlist")
g = g.map(sns.kdeplot, "following_watchlist")

# %%
g = sns.FacetGrid(df, col="is_on_watchlist")
g = g.map(sns.kdeplot, "watchlist_completion")

# %%
g = sns.FacetGrid(df, col="is_on_watchlist")
g = g.map(sns.kdeplot, "likes_watchlist")

# %%
g = sns.FacetGrid(df, col="is_on_watchlist")
g = g.map(sns.kdeplot, "retweets_watchlist")

# %%
g = sns.FacetGrid(df, col="is_on_watchlist")
g = g.map(sns.kdeplot, "mentions_watchlist")

# %%
g = sns.FacetGrid(df, col="is_on_watchlist")
g = g.map(sns.kdeplot, "watchword_in_bio")

# %%
sns.heatmap(df.corr(), cmap="RdBu_r", vmin=-1, vmax=1)

# %%
df.corr()
# Out:
#                       following_watchlist  watchlist_completion  \
# following_watchlist              1.000000              0.201074
# watchlist_completion             0.201074              1.000000
# likes_watchlist                  0.498107              0.286715
# retweets_watchlist               0.244751              0.199043
# mentions_watchlist               0.173128              0.142381
# watchword_in_bio                 0.180797              0.188508
# is_on_watchlist                  0.289380              0.399570
#
#                       likes_watchlist  retweets_watchlist  mentions_watchlist  \
# following_watchlist          0.498107            0.244751            0.173128
# watchlist_completion         0.286715            0.199043            0.142381
# likes_watchlist              1.000000            0.575295            0.336514
# retweets_watchlist           0.575295            1.000000            0.294975
# mentions_watchlist           0.336514            0.294975            1.000000
# watchword_in_bio             0.291863            0.200645            0.104179
# is_on_watchlist              0.427346            0.366100            0.206932
#
#                       watchword_in_bio  is_on_watchlist
# following_watchlist           0.180797         0.289380
# watchlist_completion          0.188508         0.399570
# likes_watchlist               0.291863         0.427346
# retweets_watchlist            0.200645         0.366100
# mentions_watchlist            0.104179         0.206932
# watchword_in_bio              1.000000         0.319648
# is_on_watchlist               0.319648         1.000000

# %%
df[df['is_on_watchlist']==1].describe()
# Out:
#        following_watchlist  watchlist_completion  likes_watchlist  \
# count           685.000000            685.000000       685.000000
# mean              0.022974              0.007783         0.111772
# std               0.053554              0.012463         0.165376
# min               0.000000              0.000000         0.000000
# 25%               0.001610              0.001111         0.009615
# 50%               0.007812              0.003333         0.050000
# 75%               0.022440              0.010000         0.139130
# max               1.000000              0.103333         1.000000
#
#        retweets_watchlist  mentions_watchlist  watchword_in_bio  \
# count          685.000000          685.000000        685.000000
# mean             0.102689            0.047776          0.189781
# std              0.183871            0.160812          0.392414
# min              0.000000            0.000000          0.000000
# 25%              0.000000            0.000000          0.000000
# 50%              0.035714            0.000000          0.000000
# 75%              0.114583            0.000000          0.000000
# max              1.000000            1.000000          1.000000
#
#        is_on_watchlist
# count            685.0
# mean               1.0
# std                0.0
# min                1.0
# 25%                1.0
# 50%                1.0
# 75%                1.0
# max                1.0

# %%
df[df['is_on_watchlist']==0].describe()
# Out:
#        following_watchlist  watchlist_completion  likes_watchlist  \
# count           713.000000            713.000000       713.000000
# mean              0.000308              0.000165         0.001981
# std               0.001698              0.000797         0.014095
# min               0.000000              0.000000         0.000000
# 25%               0.000000              0.000000         0.000000
# 50%               0.000000              0.000000         0.000000
# 75%               0.000000              0.000000         0.000000
# max               0.022222              0.015556         0.256410
#
#        retweets_watchlist  mentions_watchlist  watchword_in_bio  \
# count          713.000000          713.000000        713.000000
# mean             0.001235            0.000165          0.002805
# std              0.012329            0.004406          0.052926
# min              0.000000            0.000000          0.000000
# 25%              0.000000            0.000000          0.000000
# 50%              0.000000            0.000000          0.000000
# 75%              0.000000            0.000000          0.000000
# max              0.269231            0.117647          1.000000
#
#        is_on_watchlist
# count            713.0
# mean               0.0
# std                0.0
# min                0.0
# 25%                0.0
# 50%                0.0
# 75%                0.0
# max                0.0

# %%
conn.close()
