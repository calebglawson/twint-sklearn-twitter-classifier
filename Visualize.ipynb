# %%
import pandas as pd
import sqlite3
conn = sqlite3.connect("intake.db")
df = pd.read_sql_query("select * from user_stats;", conn)
df.head()
conn.close()

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

g = sns.FacetGrid(df, col="is_on_watchlist")
g = g.map(sns.kdeplot, "following_watchlist")

# %%
g = sns.FacetGrid(df, col="is_on_watchlist")
g = g.map(sns.kdeplot, "watchlist_completion")

# %%
g = sns.FacetGrid(df, col="is_on_watchlist")
g = g.map(sns.kdeplot, "likes_watchlist")

# %%
g = sns.FacetGrid(df, col="is_on_watchlist")
g = g.map(sns.kdeplot, "retweets_watchlist")

# %%
g = sns.FacetGrid(df, col="is_on_watchlist")
g = g.map(sns.kdeplot, "mentions_watchlist")

# %%
g = sns.FacetGrid(df, col="is_on_watchlist")
g = g.map(sns.kdeplot, "tweet_watchword_ratio")

# %%
g = sns.FacetGrid(df, col="is_on_watchlist")
g = g.map(sns.kdeplot, "neg")

# %%
g = sns.FacetGrid(df, col="is_on_watchlist")
g = g.map(sns.kdeplot, "neu")

# %%
g = sns.FacetGrid(df, col="is_on_watchlist")
g = g.map(sns.kdeplot, "pos")

# %%
g = sns.FacetGrid(df, col="is_on_watchlist")
g = g.map(sns.kdeplot, "compound")

# %%
g = sns.FacetGrid(df, col="is_on_watchlist")
g = g.map(sns.kdeplot, "watchword_in_bio")

# %%
sns.heatmap(df.corr(), cmap="RdBu_r", vmin=-1, vmax=1)

# %%
df.corr()
# Out:
#                        following_watchlist  watchlist_completion  \
# following_watchlist               1.000000              0.180789
# watchlist_completion              0.180789              1.000000
# likes_watchlist                   0.497503              0.273932
# retweets_watchlist                0.220195              0.189416
# mentions_watchlist                0.186815              0.176791
# tweet_watchword_ratio             0.271073              0.091205
# neg                               0.102798              0.144090
# neu                               0.044620              0.097299
# pos                               0.032624              0.009786
# compound                         -0.084508             -0.115723
# watchword_in_bio                  0.165570              0.185187
# is_on_watchlist                   0.255929              0.372430
#
#                        likes_watchlist  retweets_watchlist  \
# ...

# %%
df[df['is_on_watchlist']==1].describe()
# Out:
#        following_watchlist  watchlist_completion  likes_watchlist  \
# count           486.000000            486.000000       486.000000
# mean              0.023064              0.007396         0.109540
# std               0.060278              0.012642         0.171085
# min               0.000000              0.000000         0.000000
# 25%               0.000348              0.001111         0.008547
# 50%               0.006250              0.002222         0.043669
# 75%               0.020569              0.008889         0.135596
# max               1.000000              0.092222         1.000000
#
#        retweets_watchlist  mentions_watchlist  tweet_watchword_ratio  \
# count          486.000000           486.00000             486.000000
# mean             0.100949             0.04334               0.119708
# std              0.192425             0.15723               0.162293
# min              0.000000             0.00000               0.000000
# ...

# %%
df[df['is_on_watchlist']==0].describe()
# Out:
#        following_watchlist  watchlist_completion  likes_watchlist  \
# count           472.000000            472.000000       472.000000
# mean              0.000341              0.000167         0.002195
# std               0.001844              0.000624         0.015578
# min               0.000000              0.000000         0.000000
# 25%               0.000000              0.000000         0.000000
# 50%               0.000000              0.000000         0.000000
# 75%               0.000000              0.000000         0.000000
# max               0.022222              0.005556         0.256410
#
#        retweets_watchlist  mentions_watchlist  tweet_watchword_ratio  \
# count          472.000000          472.000000             472.000000
# mean             0.001775            0.000249               0.011512
# std              0.015085            0.005415               0.038847
# min              0.000000            0.000000               0.000000
# ...

# %%
conn.close()
